# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Working with Data: Pandas

# %% [markdown]
# ![](https://images.csmonitor.com/csm/2015/10/944693_1_1029%20panda%20diplomacy_standard.jpg?alias=standard_900x600nc)

# %% [markdown]
# **NOT THAT TYPE OF PANDAS**
#
# ![Pandas logo](https://pandas.pydata.org/_static/pandas_logo.png)

# %% [markdown]
# *"pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language"*
#
# https://pandas.pydata.org

# %% [markdown]
# How to get started?

# %%
import pandas as pd

# %% [markdown]
# Make sure you have the file "firearm-combined.csv" in the current directory. If not copy it here or go work there!

# %%
ls
# Out:
# Lecture 9.ipynb        firearms-combined.csv  lecture9.pdf

# %% [markdown]
# Now let's read the data from the CSV file into a dataframe:

# %%
# fixed field width is another common type of data, where each field is a "fixed" width. CSV is easier to read.
df = pd.read_csv("firearms-combined.csv")

# %% [markdown]
# ### What is a dataframe?

# %% [markdown]
# A dataframe is like an Excel spreadsheet within Python:

# %%
df
# Out:
#    STATE  RATE-2005  RATE-2014  Total Laws 2014
# 0     AL       16.0       16.9               10
# 1     AK       17.5       19.2                3
# 2     AZ       16.1       13.5                8
# 3     AR       15.7       16.6               11
# 4     CA        9.5        7.4              100
# 5     CO       11.6       12.2               30
# 6     CT        5.3        5.0               85
# 7     DE        8.8       11.1               38
# 8     FL       10.0       11.5               21
# 9     GA       12.1       13.7                6
# 10    HI        2.1        2.6               78
# 11    ID       14.1       13.2                5
# 12    IL        8.0        9.0               65
# 13    IN       11.2       12.4               11
# 14    IA        6.7        7.5               25
# 15    KS        9.3       11.3                8
# 16    KY       13.0       13.9                7
# 17    LA       18.5       19.0               12
# 18    ME        7.8        9.4               11
# 19    MD       11.9        9.0               63
# 20    MA        3.4        3.2              101
# 21    MI       10.8       11.1               20
# 22    MN        7.0        6.6               39
# 23    MS       16.0       18.3                5
# 24    MO       12.9       15.3                8
# 25    MT       16.9       16.1                4
# 26    NE        7.7        9.5               22
# 27    NV       16.1       14.8               11
# 28    NH        6.6        8.7               10
# 29    NJ        5.2        5.3               67
# 30    NM       13.9       16.0               10
# 31    NY        5.3        4.2               76
# 32    NC       12.8       11.8               30
# 33    ND        8.8       12.3               14
# 34    OH        9.6       10.3               15
# 35    OK       13.2       15.7                9
# 36    OR       10.7       11.7               24
# 37    PA       10.8       10.5               37
# 38    RI        3.6        3.0               43
# 39    SC       13.8       15.5               12
# 40    SD       10.2       10.3                5
# 41    TN       16.0       15.1               24
# 42    TX       11.1       10.7               20
# 43    UT       10.1       12.3               11
# 44    VT        6.8       10.3                3
# 45    VA       11.5       10.3               12
# 46    WA        8.8        9.7               41
# 47    WV       13.8       14.6               24
# 48    WI        8.5        8.2               24
# 49    WY       13.4       16.2                6

# %% [markdown]
# It is a two-dimennsional set of data, where the rows and columns can have labels. We can retrieve the data using these labels:

# %%
df['STATE']
# Out:
# 0     AL
# 1     AK
# 2     AZ
# 3     AR
# 4     CA
# 5     CO
# 6     CT
# 7     DE
# 8     FL
# 9     GA
# 10    HI
# 11    ID
# 12    IL
# 13    IN
# 14    IA
# 15    KS
# 16    KY
# 17    LA
# 18    ME
# 19    MD
# 20    MA
# 21    MI
# 22    MN
# 23    MS
# 24    MO
# 25    MT
# 26    NE
# 27    NV
# 28    NH
# 29    NJ
# 30    NM
# 31    NY
# 32    NC
# 33    ND
# 34    OH
# 35    OK
# 36    OR
# 37    PA
# 38    RI
# 39    SC
# 40    SD
# 41    TN
# 42    TX
# 43    UT
# 44    VT
# 45    VA
# 46    WA
# 47    WV
# 48    WI
# 49    WY
# Name: STATE, dtype: object

# %% [markdown]
# Note that a colum  of a dataframe is returned as a pandas series:

# %%
type(df['STATE'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# A Pandas series is a one-dimensional data object with row labels

# %% [markdown]
# When you import from a CSV file, the column labels are imported, but the row labels are just the numbers of the data rows:

# %%
df.loc[8]
# Out:
# STATE                FL
# RATE-2005            10
# RATE-2014          11.5
# Total Laws 2014      21
# Name: 8, dtype: object

# %% [markdown]
# It is often convenient to use the values in one of the columns as the labels of the rows. We call these the *index* for the rows:

# %%
df.set_index('STATE')
# Out:
#        RATE-2005  RATE-2014  Total Laws 2014
# STATE
# AL          16.0       16.9               10
# AK          17.5       19.2                3
# AZ          16.1       13.5                8
# AR          15.7       16.6               11
# CA           9.5        7.4              100
# CO          11.6       12.2               30
# CT           5.3        5.0               85
# DE           8.8       11.1               38
# FL          10.0       11.5               21
# GA          12.1       13.7                6
# HI           2.1        2.6               78
# ID          14.1       13.2                5
# IL           8.0        9.0               65
# IN          11.2       12.4               11
# IA           6.7        7.5               25
# KS           9.3       11.3                8
# KY          13.0       13.9                7
# LA          18.5       19.0               12
# ME           7.8        9.4               11
# MD          11.9        9.0               63
# MA           3.4        3.2              101
# MI          10.8       11.1               20
# MN           7.0        6.6               39
# MS          16.0       18.3                5
# MO          12.9       15.3                8
# MT          16.9       16.1                4
# NE           7.7        9.5               22
# NV          16.1       14.8               11
# NH           6.6        8.7               10
# NJ           5.2        5.3               67
# NM          13.9       16.0               10
# NY           5.3        4.2               76
# NC          12.8       11.8               30
# ND           8.8       12.3               14
# OH           9.6       10.3               15
# OK          13.2       15.7                9
# OR          10.7       11.7               24
# PA          10.8       10.5               37
# RI           3.6        3.0               43
# SC          13.8       15.5               12
# SD          10.2       10.3                5
# TN          16.0       15.1               24
# TX          11.1       10.7               20
# UT          10.1       12.3               11
# VT           6.8       10.3                3
# VA          11.5       10.3               12
# WA           8.8        9.7               41
# WV          13.8       14.6               24
# WI           8.5        8.2               24
# WY          13.4       16.2                6

# %% [markdown]
# Note that that is actually returning a new dataframe and the original dataframe is unchanged:

# %%
df
# Out:
#    STATE  RATE-2005  RATE-2014  Total Laws 2014
# 0     AL       16.0       16.9               10
# 1     AK       17.5       19.2                3
# 2     AZ       16.1       13.5                8
# 3     AR       15.7       16.6               11
# 4     CA        9.5        7.4              100
# 5     CO       11.6       12.2               30
# 6     CT        5.3        5.0               85
# 7     DE        8.8       11.1               38
# 8     FL       10.0       11.5               21
# 9     GA       12.1       13.7                6
# 10    HI        2.1        2.6               78
# 11    ID       14.1       13.2                5
# 12    IL        8.0        9.0               65
# 13    IN       11.2       12.4               11
# 14    IA        6.7        7.5               25
# 15    KS        9.3       11.3                8
# 16    KY       13.0       13.9                7
# 17    LA       18.5       19.0               12
# 18    ME        7.8        9.4               11
# 19    MD       11.9        9.0               63
# 20    MA        3.4        3.2              101
# 21    MI       10.8       11.1               20
# 22    MN        7.0        6.6               39
# 23    MS       16.0       18.3                5
# 24    MO       12.9       15.3                8
# 25    MT       16.9       16.1                4
# 26    NE        7.7        9.5               22
# 27    NV       16.1       14.8               11
# 28    NH        6.6        8.7               10
# 29    NJ        5.2        5.3               67
# 30    NM       13.9       16.0               10
# 31    NY        5.3        4.2               76
# 32    NC       12.8       11.8               30
# 33    ND        8.8       12.3               14
# 34    OH        9.6       10.3               15
# 35    OK       13.2       15.7                9
# 36    OR       10.7       11.7               24
# 37    PA       10.8       10.5               37
# 38    RI        3.6        3.0               43
# 39    SC       13.8       15.5               12
# 40    SD       10.2       10.3                5
# 41    TN       16.0       15.1               24
# 42    TX       11.1       10.7               20
# 43    UT       10.1       12.3               11
# 44    VT        6.8       10.3                3
# 45    VA       11.5       10.3               12
# 46    WA        8.8        9.7               41
# 47    WV       13.8       14.6               24
# 48    WI        8.5        8.2               24
# 49    WY       13.4       16.2                6

# %% [markdown]
# If we wish to work with the original one, we have to replace it

# %%
df = df.set_index("STATE")
df
# Out:
#        RATE-2005  RATE-2014  Total Laws 2014
# STATE
# AL          16.0       16.9               10
# AK          17.5       19.2                3
# AZ          16.1       13.5                8
# AR          15.7       16.6               11
# CA           9.5        7.4              100
# CO          11.6       12.2               30
# CT           5.3        5.0               85
# DE           8.8       11.1               38
# FL          10.0       11.5               21
# GA          12.1       13.7                6
# HI           2.1        2.6               78
# ID          14.1       13.2                5
# IL           8.0        9.0               65
# IN          11.2       12.4               11
# IA           6.7        7.5               25
# KS           9.3       11.3                8
# KY          13.0       13.9                7
# LA          18.5       19.0               12
# ME           7.8        9.4               11
# MD          11.9        9.0               63
# MA           3.4        3.2              101
# MI          10.8       11.1               20
# MN           7.0        6.6               39
# MS          16.0       18.3                5
# MO          12.9       15.3                8
# MT          16.9       16.1                4
# NE           7.7        9.5               22
# NV          16.1       14.8               11
# NH           6.6        8.7               10
# NJ           5.2        5.3               67
# NM          13.9       16.0               10
# NY           5.3        4.2               76
# NC          12.8       11.8               30
# ND           8.8       12.3               14
# OH           9.6       10.3               15
# OK          13.2       15.7                9
# OR          10.7       11.7               24
# PA          10.8       10.5               37
# RI           3.6        3.0               43
# SC          13.8       15.5               12
# SD          10.2       10.3                5
# TN          16.0       15.1               24
# TX          11.1       10.7               20
# UT          10.1       12.3               11
# VT           6.8       10.3                3
# VA          11.5       10.3               12
# WA           8.8        9.7               41
# WV          13.8       14.6               24
# WI           8.5        8.2               24
# WY          13.4       16.2                6

# %% [markdown]
# This makes indexing much easier

# %%
df.loc["FL"]
# Out:
# RATE-2005          10.0
# RATE-2014          11.5
# Total Laws 2014    21.0
# Name: FL, dtype: float64

# %% [markdown]
# Note that the row labels carry over to the Pandas series that is returned by indexing a particular column of the dataframe:

# %%
# TODO

# %% [markdown]
# If all we want is the numerical values in the data series, we can convert it to a list:

# %%
# TODO
# list(df.)

# %% [markdown]
# Now that we know some basics of working with Pandas dataframes and series, we can begin to work with real data:

# %% [markdown]
# ## Effect of 2004 Assault Weapons Ban

# %% [markdown]
# In 2004, the United State Congress passed a ban on a variety of semiautomatic rifles that are sometimes referred to as "assault weapons". The ban was in effect for 10 years, from 2004–2014
#
# It might be guessed that the goal of any gun ban is to reduced gun violence. Thus it is natural to assess whether the "assault weapon" ban had any effect on gun violence

# %% [markdown]
# Fortunately, the Center for Disease Control's National Center for Health Statistics tracks firearm mortality at the state level. Visualizations of firearm mortality by state, along with links to download the data are available here:
#
# https://www.cdc.gov/nchs/pressroom/sosmap/firearm_mortality/firearm.htm

# %% [markdown]
# Although this page does not have data prior to 2005, the data for 2005 should be similar to that before the ban because the ban was only on the **sale** of certain firearms. It would take many years for this ban to actually affect the availability of firearms

# %% [markdown]
# Thus, we can use two sets of data on that page to measure the effect of the "assault weapons" ban:
#
# * The 2005 data set represents firearm mortaility before the ban
# * The 2014 data set represents firearm mortality after the ban has been in effect for a decade. Let's begin by plotting this data:

# %%
# This step is not necessary but will simplify our work later:
rate2005=list(df["RATE-2005"])
rate2014=list(df["RATE-2014"])

# %% [markdown]
# Generally, one of the first visualizations to undertake with any data set is a scatter plot. Since we have two one-dimensional data sets, we can scatter plot each of them in the y-axis, where the x-axis is used to indicate which data set they come from:

# %%
plt.scatter(np.ones(50)*2005, rate2005)
plt.scatter(np.ones(50)*2014, rate2014)

# %% [markdown]
# What inferences might you make from this plot?

# %% [markdown]
# We could also scatter plot them versus the index of the state they came from:

# %%
plt.scatter(np.linspace(1,50,50), rate2005)
plt.scatter(np.linspace(1,50,50), rate2014)

# %% [markdown]
# This is  a jumbled mess. We could try to provide some order by sorting the lists. However, with two lists, it might not make sense to sort them separately. We can get the list of indices that would sort one list and then use that to order both lists.
#
# To do that, we need to first understand a numpy capability called *fancy indexing*
#
# Fancy indexing allows you to retrieve members of an array in any order by just indexing with a list of the indices:

# %%
squares=np.array([0,1,4,9,16,25,36,49])

# %% [markdown]
# To retrieve the squares of the prime numbers, I can make a list of primes and then use that as an index:

# %%
primes=[2,3,5,7]
squares[primes]
# Out:
# array([ 4,  9, 25, 49])

# %% [markdown]
# The index list does not have to be in increasing order:

# %%
rprimes=primes[::-1]
rprimes
# Out:
# [7, 5, 3, 2]

# %%
squares[rprimes]
# Out:
# array([49, 25,  9,  4])

# %% [markdown]
# ```numpy.argsort``` returns a list of the indices that will sort an array:

# %%
order = np.argsort(rate2005)
order
# Out:
# array([10, 20, 38, 29,  6, 31, 28, 14, 44, 22, 26, 18, 12, 48,  7, 46, 33,
#        15,  4, 34,  8, 43, 40, 36, 37, 21, 42, 13, 45,  5, 19,  9, 32, 24,
#        16, 35, 49, 39, 47, 30, 11,  3, 23, 41,  0, 27,  2, 25,  1, 17])

# %%
rate2005=np.array(rate2005)
rate2014=np.array(rate2014)

# %%
rate2005[order]
# Out:
# array([ 2.1,  3.4,  3.6,  5.2,  5.3,  5.3,  6.6,  6.7,  6.8,  7. ,  7.7,
#         7.8,  8. ,  8.5,  8.8,  8.8,  8.8,  9.3,  9.5,  9.6, 10. , 10.1,
#        10.2, 10.7, 10.8, 10.8, 11.1, 11.2, 11.5, 11.6, 11.9, 12.1, 12.8,
#        12.9, 13. , 13.2, 13.4, 13.8, 13.8, 13.9, 14.1, 15.7, 16. , 16. ,
#        16. , 16.1, 16.1, 16.9, 17.5, 18.5])

# %%
plt.scatter(np.linspace(1,50,50), rate2005[order])
plt.scatter(np.linspace(1,50,50), rate2014[order])

# %% [markdown]
# What inferences might you make from this plot?

# %% [markdown]
# Another common visualization is to look at a histogram of the data. Unlike the histograms we previously generated, this data takes on real values, not just integers. Fortunately, Matplotlib has functions to do the hard work of making histograms for us:

# %% [markdown]
# Some styling will help make this more legible:

# %% [markdown]
# Each bar of the histgram represents a "bin" of data values. In fact, the counts and bin edges are returned by the hist function

# %% [markdown]
# We can easily change the number of bins to provide more resolution:

# %% [markdown]
# However, it does not make sense to make the number of bins very large compared to the data size

# %% [markdown]
# What inferences might you make from this plot?

# %% [markdown]
# # Summary Statistics

# %% [markdown]
# Summary statistics are values calculated from sample data that measure some characteristic about the data

# %% [markdown]
# The most commonly summary statistic is ?

# %% [markdown]
# Both Pandas and Numpy provide methods to calculate the sample mean:
